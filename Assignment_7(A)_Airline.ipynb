# %% [markdown]
# # Assignment 7(A) : East West Airlines

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_excel("EastWestAirlines.xlsx")

# %%
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df8 = df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
df2 = df.groupby(df["cc2_miles"]).count()
df2
# Out:
#             ID#  Balance  Qual_miles  cc1_miles  cc3_miles  Bonus_miles  \
# cc2_miles
# 1          3956     3956        3956       3956       3956         3956
# 2            28       28          28         28         28           28
# 3            15       15          15         15         15           15
#
#            Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# cc2_miles
# 1                 3956               3956             3956               3956
# 2                   28                 28               28                 28
# 3                   15                 15               15                 15
#
#            Award?
# cc2_miles
# 1            3956
# 2              28
# 3              15

# %%
df = df.drop(["ID#"], axis = 1)

# %%
df.describe()
# Out:
#             Balance    Qual_miles    cc1_miles    cc2_miles    cc3_miles  \
# count  3.999000e+03   3999.000000  3999.000000  3999.000000  3999.000000
# mean   7.360133e+04    144.114529     2.059515     1.014504     1.012253
# std    1.007757e+05    773.663804     1.376919     0.147650     0.195241
# min    0.000000e+00      0.000000     1.000000     1.000000     1.000000
# 25%    1.852750e+04      0.000000     1.000000     1.000000     1.000000
# 50%    4.309700e+04      0.000000     1.000000     1.000000     1.000000
# 75%    9.240400e+04      0.000000     3.000000     1.000000     1.000000
# max    1.704838e+06  11148.000000     5.000000     3.000000     5.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# count    3999.000000   3999.00000        3999.000000      3999.000000
# mean    17144.846212     11.60190         460.055764         1.373593
# std     24150.967826      9.60381        1400.209171         3.793172
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df1 = sc.fit_transform(df)
df1
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
df5 = df1

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
# Normalized data frame (considering the numerical part of data)
df3 = norm_func(df)
df3
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
plt.boxplot(df1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20a8d6c0610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20a8d6c0c70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20a8d0090a0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x20a8d6ce3d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x20a8d6ce760>,
# ...
#  'means': []}

# %%
sns.distplot(df["Balance"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Balance', ylabel='Density'>

# %%
df["Award?"].value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
import scipy.cluster.hierarchy as sch

# %%
plt.figure(figsize=(10, 7))  
dendograms=sch.dendrogram(sch.linkage(df3,'complete'))

# %%
from sklearn.cluster import AgglomerativeClustering
hclusters=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='ward')
hclusters
# Out:
# AgglomerativeClustering(n_clusters=5)

# %%
y=pd.DataFrame(hclusters.fit_predict(df3),columns=['clustersid'])
y['clustersid'].value_counts()
# Out:
# 1    1011
# 0     946
# 2     808
# 4     699
# 3     535
# Name: clustersid, dtype: int64

# %%
# Adding clusters to dataset
df3['clustersid']=hclusters.labels_
df3
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df3.groupby('clustersid').agg(['mean']).reset_index()
# Out:
#   clustersid   Balance Qual_miles cc1_miles cc2_miles cc3_miles Bonus_miles  \
#                   mean       mean      mean      mean      mean        mean
# 0          0  0.046836   0.025574  0.174947  0.012156  0.000000    0.045811
# 1          1  0.025406   0.001929  0.000000  0.016815  0.000247    0.009718
# 2          2  0.062306   0.014466  0.549505  0.000619  0.006498    0.100340
# 3          3  0.074773   0.014424  0.840654  0.000000  0.012617    0.222451
# 4          4  0.017605   0.008796  0.000000  0.000000  0.000000    0.009680
#
#   Bonus_trans Flight_miles_12mo Flight_trans_12 Days_since_enroll Award?
#          mean              mean            mean              mean   mean
# 0    0.141084          0.025374        0.044717          0.526908    1.0
# 1    0.063660          0.005501        0.009873          0.595452    0.0
# 2    0.190277          0.006449        0.010531          0.526314    0.0
# ...

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(df3['clustersid'],df3['Balance'], c=hclusters.labels_)

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.cluster import DBSCAN
dbscan=DBSCAN(eps=1,min_samples=6)
dbscan.fit(df1)
# Out:
# DBSCAN(eps=1, min_samples=6)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
clusters=pd.DataFrame(dbscan.labels_,columns=['clusters'])
clusters
# Out:
#       clusters
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
# ...        ...
# 3994         1
# 3995         1
# 3996         1
# 3997         0
# 3998         0
#
# [3999 rows x 1 columns]

# %%
df['Clusters']=dbscan.labels_
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df.groupby('Clusters').agg(['mean']).reset_index()
# Out:
#   Clusters        Balance   Qual_miles cc1_miles cc2_miles cc3_miles  \
#                      mean         mean      mean      mean      mean
# 0       -1  181742.540070   931.761324  2.724739  1.057491  1.085366
# 1        0   53181.803548     3.660320  1.655993  1.000000  1.000000
# 2        1   60939.351750     9.894107  2.593923  1.000000  1.000000
# 3        2   34806.538462     0.000000  1.000000  2.000000  1.000000
# 4        3   38616.166667     0.000000  1.000000  3.000000  1.000000
# 5        4   27113.888889  2475.444444  1.000000  1.000000  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  39466.153310   22.055749       2172.263066        6.273519
# 1   9010.212462    8.451752        125.327131        0.401558
# 2  22898.413444   12.820442        278.409761        0.882136
# 3   8389.769231   12.000000         19.230769        0.153846
# ...

# %%
plt.figure(figsize=(10, 7))  
plt.scatter(df['Clusters'],df3['Balance'], c=dbscan.labels_)

# %% [markdown]
# ## K- Mean clustering

# %% [markdown]
# ## Find the number of K: Elbow method

# %%
from sklearn.cluster import KMeans

# %%
    wcss = []
    for i in range(1,11):
        model= KMeans(n_clusters=i,random_state = 2)
        model.fit(df1)
        a = model.inertia_
        wcss.append(a)


    wcss
# Out:
# [43988.99999999999,
#  35409.5166298613,
#  30899.253324696238,
#  27161.52499147039,
#  24541.329582045775,
#  21480.034335840934,
#  19880.826282129008,
#  17316.753604356494,
#  16049.684338633006,
#  14732.22988234744]

# %%
plt.plot(range(1,11),wcss)
plt.xlabel("Number of K")
plt.ylabel("WCSS")
plt.grid()

# %%
kmodel= KMeans(n_clusters=5) # by the Elbow method we select n-cluster as 5

# %%
y = kmodel.fit_predict(df5)

# %%
y
# Out:
# array([0, 0, 0, ..., 2, 0, 0])

# %%
df8["Cluster"]= y

# %%
df8["Cluster"].value_counts()
# Out:
# 0    2529
# 2    1256
# 4     139
# 1      60
# 3      15
# Name: Cluster, dtype: int64

# %%
df8
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df8.groupby('Cluster').agg(['mean']).reset_index()
# Out:
#   Cluster          ID#        Balance   Qual_miles cc1_miles cc2_miles  \
#                   mean           mean         mean      mean      mean
# 0       0  2237.098062   43595.916568    42.265322  1.224199  1.019375
# 1       1  2051.050000  118476.933333  5361.850000  1.950000  1.000000
# 2       2  1599.089172  117096.176752    59.230892  3.700637  1.002389
# 3       3  1664.866667  138061.400000    78.800000  3.466667  1.000000
# 4       4  1749.280576  200182.021583   518.978417  2.323741  1.043165
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.000395   4718.666667    6.960063        209.758798        0.642546
# 1  1.000000  17258.883333   11.883333        900.466667        2.666667
# 2  1.001592  39129.378981   18.805732        352.001592        1.050159
# 3  4.066667  93927.866667   28.066667        506.666667        1.600000
# ...

# %%
plt.figure(figsize=(10, 7))  
plt.scatter(df8['Cluster'],df8['Balance'], c=dbscan.labels_)
